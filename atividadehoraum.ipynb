# %%
import pandas as pd

# %%
url = "dataset/movies.csv"

pd.read_csv(url)
# Out:
#                                   movieId                   movieTitle  \
# 0    963448dc-df1d-3125-aa10-639748f56fb0            L.A. Confidential
# 1    5aa3be92-ee5f-3302-93a1-aba38151e6bc                The Godfather
# 2    744d4aea-e6ad-3c9a-9723-ee9b10505b98                   Casablanca
# 3    e82e8623-76fa-3a2a-9fc3-1f5ce4fb4768                Seven Samurai
# 4    a82538f5-e84b-32e8-9a49-2872b563d583                     Parasite
# ..                                    ...                          ...
# 295  144420f9-e23e-3dde-acbd-58a322954fc0         Beauty and the Beast
# 296  db9832af-407b-3c36-85c8-f1d99f614963                  The Killing
# 297  d0a2f686-cfc7-3d53-96b2-edca9b003757        The Rules of the Game
# 298  025f8085-b8fa-394b-956e-eaf4810ccb8f          Eyes Without a Face
# 299  96f91c04-5e32-39b2-805f-4c1d1bcb3b1b  The Cabinet of Dr. Caligari
#
#      movieYear                                           movieURL  movieRank  \
# ...

# %%
print(type(url))
# Out:
# <class 'str'>

# %%
pd.read_csv(url,sep=";")
# Out:
#     movieId,"movieTitle","movieYear","movieURL","movieRank","critic_score","audience_score"
# 0    963448dc-df1d-3125-aa10-639748f56fb0,"L.A. Con...
# 1    5aa3be92-ee5f-3302-93a1-aba38151e6bc,"The Godf...
# 2    744d4aea-e6ad-3c9a-9723-ee9b10505b98,"Casablan...
# 3    e82e8623-76fa-3a2a-9fc3-1f5ce4fb4768,"Seven Sa...
# 4    a82538f5-e84b-32e8-9a49-2872b563d583,"Parasite...
# ..                                                 ...
# 295  144420f9-e23e-3dde-acbd-58a322954fc0,"Beauty a...
# 296  db9832af-407b-3c36-85c8-f1d99f614963,"The Kill...
# 297  d0a2f686-cfc7-3d53-96b2-edca9b003757,"The Rule...
# 298  025f8085-b8fa-394b-956e-eaf4810ccb8f,"Eyes Wit...
# 299  96f91c04-5e32-39b2-805f-4c1d1bcb3b1b,"The Cabi...
#
# [300 rows x 1 columns]

# %%
dados = pd.read_csv(url,sep=";")
dados
# Out:
#     movieId,"movieTitle","movieYear","movieURL","movieRank","critic_score","audience_score"
# 0    963448dc-df1d-3125-aa10-639748f56fb0,"L.A. Con...
# 1    5aa3be92-ee5f-3302-93a1-aba38151e6bc,"The Godf...
# 2    744d4aea-e6ad-3c9a-9723-ee9b10505b98,"Casablan...
# 3    e82e8623-76fa-3a2a-9fc3-1f5ce4fb4768,"Seven Sa...
# 4    a82538f5-e84b-32e8-9a49-2872b563d583,"Parasite...
# ..                                                 ...
# 295  144420f9-e23e-3dde-acbd-58a322954fc0,"Beauty a...
# 296  db9832af-407b-3c36-85c8-f1d99f614963,"The Kill...
# 297  d0a2f686-cfc7-3d53-96b2-edca9b003757,"The Rule...
# 298  025f8085-b8fa-394b-956e-eaf4810ccb8f,"Eyes Wit...
# 299  96f91c04-5e32-39b2-805f-4c1d1bcb3b1b,"The Cabi...
#
# [300 rows x 1 columns]

# %%
dados.head()
# Out:
#   movieId,"movieTitle","movieYear","movieURL","movieRank","critic_score","audience_score"
# 0  963448dc-df1d-3125-aa10-639748f56fb0,"L.A. Con...
# 1  5aa3be92-ee5f-3302-93a1-aba38151e6bc,"The Godf...
# 2  744d4aea-e6ad-3c9a-9723-ee9b10505b98,"Casablan...
# 3  e82e8623-76fa-3a2a-9fc3-1f5ce4fb4768,"Seven Sa...
# 4  a82538f5-e84b-32e8-9a49-2872b563d583,"Parasite...

# %%
dados.head(15)
# Out:
#    movieId,"movieTitle","movieYear","movieURL","movieRank","critic_score","audience_score"
# 0   963448dc-df1d-3125-aa10-639748f56fb0,"L.A. Con...
# 1   5aa3be92-ee5f-3302-93a1-aba38151e6bc,"The Godf...
# 2   744d4aea-e6ad-3c9a-9723-ee9b10505b98,"Casablan...
# 3   e82e8623-76fa-3a2a-9fc3-1f5ce4fb4768,"Seven Sa...
# 4   a82538f5-e84b-32e8-9a49-2872b563d583,"Parasite...
# 5   dc41988b-1081-351f-b735-95ce61a8f5ad,"Schindle...
# 6   db97d08b-0855-3d42-890f-829fddbdb1fa,"Top Gun:...
# 7   6bacd7ec-76c9-3f40-b69a-cde708c3ac01,"Toy Stor...
# 8   a64d86c4-8a6b-39f9-a750-23b12f06adbf,"Chinatow...
# 9   065fb5ae-802f-39c0-bd91-8e8757e53f1f,"On the W...
# 10  ae237566-9a4e-3ddd-8d11-8b17902f0660,"The Batt...
# 11  48f742e7-d657-38bc-ad26-ff9e52e79073,"Toy Stor...
# 12  3f6ec438-dabc-3e8a-b27a-cc859c66d065,"Rear Win...
# 13  9499525e-338d-3fd9-bb20-503b61f9a446,"Modern T...
# 14  cce9361c-4dba-3321-9d0a-60a8623c465c,"How to T...

# %%
dados.tail()
# Out:
#     movieId,"movieTitle","movieYear","movieURL","movieRank","critic_score","audience_score"
# 295  144420f9-e23e-3dde-acbd-58a322954fc0,"Beauty a...
# 296  db9832af-407b-3c36-85c8-f1d99f614963,"The Kill...
# 297  d0a2f686-cfc7-3d53-96b2-edca9b003757,"The Rule...
# 298  025f8085-b8fa-394b-956e-eaf4810ccb8f,"Eyes Wit...
# 299  96f91c04-5e32-39b2-805f-4c1d1bcb3b1b,"The Cabi...

# %%
dados.tail(20)
# Out:
#     movieId,"movieTitle","movieYear","movieURL","movieRank","critic_score","audience_score"
# 280  bd1b0cd8-1ad4-3ae0-a486-4ef8229a9cfa,"To Be or...
# 281  f1efa382-320c-309b-b4dd-070b99af6349,"All the ...
# 282  77bc0c7d-7fa0-389a-9715-e3760c829f0a,"Throne o...
# 283  993b9b59-ddb6-3102-9e25-07da7d9338a8,"Taxi Dri...
# 284  5262e09f-76e7-36c6-a804-9bd8a6d252b3,"The Big ...
# 285  f362b9f5-57e0-3021-a310-ececbcf2f49f,"Marvel's...
# 286  8dba6b0a-f663-3530-b085-b7913009ede7,"Secrets ...
# 287  48dedda4-ac2f-3ebf-9432-dcd42eb37521,"Dog Day ...
# 288  f312c634-a621-3f33-8c6b-98ef9980dbe8,"Being Th...
# 289  de8ac79a-f096-3eee-a312-13aa98115efe,"Aguirre:...
# 290  7475c7be-5ac6-3f6d-992e-9be0d1d7ecdb,"Arrival"...
# 291  22dbdeaa-bc3c-378f-8d61-a58e30d43b25,"Wings of...
# 292  5e3ba06e-652d-3bd5-93fc-e366f95da2d6,"Raging B...
# 293  77f19acc-aac9-3385-a97c-7fd0c9747977,"Fruitval...
# 294  396e1190-3550-317a-bb0c-5308655b3f22,"La Dolce...
# ...

# %%
"""
    Mostrando o tipo da minha variável 
"""
type(dados)
# Out:
# pandas.core.frame.DataFrame
