# %%
import pandas as pd

# %%
url = "dataset/movies.csv"

pd.read_csv(url)
# Out:
#                                   movieId                   movieTitle  \
# 0    963448dc-df1d-3125-aa10-639748f56fb0            L.A. Confidential
# 1    5aa3be92-ee5f-3302-93a1-aba38151e6bc                The Godfather
# 2    744d4aea-e6ad-3c9a-9723-ee9b10505b98                   Casablanca
# 3    e82e8623-76fa-3a2a-9fc3-1f5ce4fb4768                Seven Samurai
# 4    a82538f5-e84b-32e8-9a49-2872b563d583                     Parasite
# ..                                    ...                          ...
# 295  144420f9-e23e-3dde-acbd-58a322954fc0         Beauty and the Beast
# 296  db9832af-407b-3c36-85c8-f1d99f614963                  The Killing
# 297  d0a2f686-cfc7-3d53-96b2-edca9b003757        The Rules of the Game
# 298  025f8085-b8fa-394b-956e-eaf4810ccb8f          Eyes Without a Face
# 299  96f91c04-5e32-39b2-805f-4c1d1bcb3b1b  The Cabinet of Dr. Caligari
#
#      movieYear                                           movieURL  movieRank  \
# ...

# %%
print(type(url))
# Out:
# <class 'str'>

# %%
pd.read_csv(url,sep=";")
# Out:
#     movieId,"movieTitle","movieYear","movieURL","movieRank","critic_score","audience_score"
# 0    963448dc-df1d-3125-aa10-639748f56fb0,"L.A. Con...
# 1    5aa3be92-ee5f-3302-93a1-aba38151e6bc,"The Godf...
# 2    744d4aea-e6ad-3c9a-9723-ee9b10505b98,"Casablan...
# 3    e82e8623-76fa-3a2a-9fc3-1f5ce4fb4768,"Seven Sa...
# 4    a82538f5-e84b-32e8-9a49-2872b563d583,"Parasite...
# ..                                                 ...
# 295  144420f9-e23e-3dde-acbd-58a322954fc0,"Beauty a...
# 296  db9832af-407b-3c36-85c8-f1d99f614963,"The Kill...
# 297  d0a2f686-cfc7-3d53-96b2-edca9b003757,"The Rule...
# 298  025f8085-b8fa-394b-956e-eaf4810ccb8f,"Eyes Wit...
# 299  96f91c04-5e32-39b2-805f-4c1d1bcb3b1b,"The Cabi...
#
# [300 rows x 1 columns]

# %%
dados = pd.read_csv(url)
dados
# Out:
#                                   movieId                   movieTitle  \
# 0    963448dc-df1d-3125-aa10-639748f56fb0            L.A. Confidential
# 1    5aa3be92-ee5f-3302-93a1-aba38151e6bc                The Godfather
# 2    744d4aea-e6ad-3c9a-9723-ee9b10505b98                   Casablanca
# 3    e82e8623-76fa-3a2a-9fc3-1f5ce4fb4768                Seven Samurai
# 4    a82538f5-e84b-32e8-9a49-2872b563d583                     Parasite
# ..                                    ...                          ...
# 295  144420f9-e23e-3dde-acbd-58a322954fc0         Beauty and the Beast
# 296  db9832af-407b-3c36-85c8-f1d99f614963                  The Killing
# 297  d0a2f686-cfc7-3d53-96b2-edca9b003757        The Rules of the Game
# 298  025f8085-b8fa-394b-956e-eaf4810ccb8f          Eyes Without a Face
# 299  96f91c04-5e32-39b2-805f-4c1d1bcb3b1b  The Cabinet of Dr. Caligari
#
#      movieYear                                           movieURL  movieRank  \
# ...

# %%
dados.head()
# Out:
#                                 movieId         movieTitle  movieYear  \
# 0  963448dc-df1d-3125-aa10-639748f56fb0  L.A. Confidential       1997
# 1  5aa3be92-ee5f-3302-93a1-aba38151e6bc      The Godfather       1972
# 2  744d4aea-e6ad-3c9a-9723-ee9b10505b98         Casablanca       1942
# 3  e82e8623-76fa-3a2a-9fc3-1f5ce4fb4768      Seven Samurai       1954
# 4  a82538f5-e84b-32e8-9a49-2872b563d583           Parasite       2019
#
#                                             movieURL  movieRank critic_score  \
# 0   https://www.rottentomatoes.com/m/la_confidential          1          99%
# 1     https://www.rottentomatoes.com/m/the_godfather          2          97%
# 2  https://www.rottentomatoes.com/m/1003707-casab...          3          99%
# 3  https://www.rottentomatoes.com/m/seven_samurai...          4         100%
# 4     https://www.rottentomatoes.com/m/parasite_2019          5          99%
#
#   audience_score
# 0            94%
# 1            98%
# 2            95%
# ...

# %%
dados.head(15)
# Out:
#                                  movieId                movieTitle  movieYear  \
# 0   963448dc-df1d-3125-aa10-639748f56fb0         L.A. Confidential       1997
# 1   5aa3be92-ee5f-3302-93a1-aba38151e6bc             The Godfather       1972
# 2   744d4aea-e6ad-3c9a-9723-ee9b10505b98                Casablanca       1942
# 3   e82e8623-76fa-3a2a-9fc3-1f5ce4fb4768             Seven Samurai       1954
# 4   a82538f5-e84b-32e8-9a49-2872b563d583                  Parasite       2019
# 5   dc41988b-1081-351f-b735-95ce61a8f5ad          Schindler's List       1993
# 6   db97d08b-0855-3d42-890f-829fddbdb1fa         Top Gun: Maverick       2022
# 7   6bacd7ec-76c9-3f40-b69a-cde708c3ac01               Toy Story 2       1999
# 8   a64d86c4-8a6b-39f9-a750-23b12f06adbf                 Chinatown       1974
# 9   065fb5ae-802f-39c0-bd91-8e8757e53f1f         On the Waterfront       1954
# 10  ae237566-9a4e-3ddd-8d11-8b17902f0660     The Battle of Algiers       1966
# ...

# %%
dados.tail()
# Out:
#                                   movieId                   movieTitle  \
# 295  144420f9-e23e-3dde-acbd-58a322954fc0         Beauty and the Beast
# 296  db9832af-407b-3c36-85c8-f1d99f614963                  The Killing
# 297  d0a2f686-cfc7-3d53-96b2-edca9b003757        The Rules of the Game
# 298  025f8085-b8fa-394b-956e-eaf4810ccb8f          Eyes Without a Face
# 299  96f91c04-5e32-39b2-805f-4c1d1bcb3b1b  The Cabinet of Dr. Caligari
#
#      movieYear                                           movieURL  movieRank  \
# 295       1946  https://www.rottentomatoes.com/m/1001902-beaut...        296
# 296       1956           https://www.rottentomatoes.com/m/killing        297
# 297       1939  https://www.rottentomatoes.com/m/the_rules_of_...        298
# 298       1960  https://www.rottentomatoes.com/m/eyes_without_...        299
# 299       1919  https://www.rottentomatoes.com/m/the_cabinet_o...        300
#
#     critic_score audience_score
# 295          96%            90%
# ...

# %%
dados.tail(20)
# Out:
#                                   movieId                   movieTitle  \
# 280  bd1b0cd8-1ad4-3ae0-a486-4ef8229a9cfa           To Be or Not to Be
# 281  f1efa382-320c-309b-b4dd-070b99af6349      All the President's Men
# 282  77bc0c7d-7fa0-389a-9715-e3760c829f0a              Throne of Blood
# 283  993b9b59-ddb6-3102-9e25-07da7d9338a8                  Taxi Driver
# 284  5262e09f-76e7-36c6-a804-9bd8a6d252b3                The Big Sleep
# 285  f362b9f5-57e0-3021-a310-ececbcf2f49f        Marvel's the Avengers
# 286  8dba6b0a-f663-3530-b085-b7913009ede7               Secrets & Lies
# 287  48dedda4-ac2f-3ebf-9432-dcd42eb37521            Dog Day Afternoon
# 288  f312c634-a621-3f33-8c6b-98ef9980dbe8                  Being There
# 289  de8ac79a-f096-3eee-a312-13aa98115efe    Aguirre: The Wrath of God
# 290  7475c7be-5ac6-3f6d-992e-9be0d1d7ecdb                      Arrival
# 291  22dbdeaa-bc3c-378f-8d61-a58e30d43b25              Wings of Desire
# ...

# %%
"""
    Mostrando o tipo da minha variável 
"""
type(dados)
# Out:
# pandas.core.frame.DataFrame
